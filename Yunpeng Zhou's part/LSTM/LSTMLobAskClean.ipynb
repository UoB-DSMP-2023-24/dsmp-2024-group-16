# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from scipy.stats import zscore
# Out:
# C:\Users\Wilson\AppData\Local\Temp\ipykernel_29648\632085283.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# WARNING:tensorflow:From C:\Users\Wilson\AppData\Roaming\Python\Python39\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Read data with 'Timestamp'
data = pd.read_csv('result.csv')

# Convert 'seconds' to timedelta and add it to the starting timestamp
data['timestamp'] = pd.to_timedelta(data['Timestamp'], unit='s') + pd.Timestamp('2025-01-02 00:00')


# Set 'timestamp' as the index
data.set_index(keys='timestamp', inplace=True)

data_ffill = data.fillna(method='ffill').dropna()


# Calculate z-scores for bid prices
z_scores = zscore(data_ffill['Ask'])

# Define threshold value
threshold = 1

# Find data points with z-score greater than threshold
outliers_indices = np.where(np.abs(z_scores) > threshold)[0]

# Remove outliers from the DataFrame
cleaned_data = data_ffill.drop(data_ffill.index[outliers_indices])

scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(cleaned_data['Ask'].values.reshape(-1,1))
# Out:
# C:\Users\Wilson\AppData\Local\Temp\ipykernel_29648\1760278101.py:11: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data_ffill = data.fillna(method='ffill').dropna()

# %%
def create_dataset(dataset, look_back=1):
    X, Y = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        X.append(a)
        Y.append(dataset[i + look_back, 0])
    return np.array(X), np.array(Y)

look_back = 1
X, Y = create_dataset(scaled_data, look_back)
X = np.reshape(X, (X.shape[0], 1, X.shape[1]))

# Split data into train and test sets
train_size = int(len(X) * 0.8)
test_size = len(X) - train_size
trainX, testX = X[0:train_size], X[train_size:len(X)]
trainY, testY = Y[0:train_size], Y[train_size:len(Y)]

# %%
# Define and compile the LSTM model
model = Sequential()
model.add(LSTM(4, input_shape=(1, look_back)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# Train the model
model.fit(trainX, trainY, epochs=50, batch_size=128, verbose=2)

# Make predictions
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

# Invert predictions to be in the original scale of 'Bid' prices
trainPredict = scaler.inverse_transform(trainPredict)
testPredict = scaler.inverse_transform(testPredict)

# Inverting the scaling for the actual values, to have them in the original scale for comparison
trainY_inv = scaler.inverse_transform([trainY])
testY_inv = scaler.inverse_transform([testY])
# Out:
# WARNING:tensorflow:From C:\Users\Wilson\AppData\Roaming\Python\Python39\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\Wilson\AppData\Roaming\Python\Python39\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/50
# WARNING:tensorflow:From C:\Users\Wilson\AppData\Roaming\Python\Python39\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 2018/2018 - 3s - loss: 0.0213 - 3s/epoch - 1ms/step
# Epoch 2/50
# 2018/2018 - 2s - loss: 8.0445e-04 - 2s/epoch - 909us/step
# Epoch 3/50
# 2018/2018 - 2s - loss: 8.0153e-04 - 2s/epoch - 903us/step
# Epoch 4/50
# 2018/2018 - 2s - loss: 8.0121e-04 - 2s/epoch - 920us/step
# Epoch 5/50
# 2018/2018 - 2s - loss: 8.0108e-04 - 2s/epoch - 906us/step
# Epoch 6/50
# 2018/2018 - 2s - loss: 8.0042e-04 - 2s/epoch - 871us/step
# Epoch 7/50
# 2018/2018 - 2s - loss: 7.9993e-04 - 2s/epoch - 868us/step
# Epoch 8/50
# 2018/2018 - 2s - loss: 7.9911e-04 - 2s/epoch - 845us/step
# Epoch 9/50
# 2018/2018 - 2s - loss: 7.9969e-04 - 2s/epoch - 868us/step
# Epoch 10/50
# 2018/2018 - 2s - loss: 7.9852e-04 - 2s/epoch - 884us/step
# Epoch 11/50
# 2018/2018 - 2s - loss: 7.9867e-04 - 2s/epoch - 898us/step
# Epoch 12/50
# 2018/2018 - 2s - loss: 7.9870e-04 - 2s/epoch - 1ms/step
# Epoch 13/50
# 2018/2018 - 2s - loss: 7.9802e-04 - 2s/epoch - 896us/step
# Epoch 14/50
# 2018/2018 - 2s - loss: 7.9854e-04 - 2s/epoch - 894us/step
# Epoch 15/50
# 2018/2018 - 2s - loss: 7.9753e-04 - 2s/epoch - 883us/step
# Epoch 16/50
# 2018/2018 - 2s - loss: 7.9777e-04 - 2s/epoch - 880us/step
# Epoch 17/50
# 2018/2018 - 2s - loss: 7.9821e-04 - 2s/epoch - 876us/step
# Epoch 18/50
# 2018/2018 - 2s - loss: 7.9681e-04 - 2s/epoch - 876us/step
# Epoch 19/50
# 2018/2018 - 2s - loss: 7.9669e-04 - 2s/epoch - 857us/step
# Epoch 20/50
# 2018/2018 - 2s - loss: 7.9720e-04 - 2s/epoch - 902us/step
# Epoch 21/50
# 2018/2018 - 2s - loss: 7.9783e-04 - 2s/epoch - 924us/step
# Epoch 22/50
# 2018/2018 - 2s - loss: 7.9683e-04 - 2s/epoch - 933us/step
# Epoch 23/50
# 2018/2018 - 2s - loss: 7.9729e-04 - 2s/epoch - 982us/step
# Epoch 24/50
# 2018/2018 - 2s - loss: 7.9718e-04 - 2s/epoch - 884us/step
# Epoch 25/50
# 2018/2018 - 2s - loss: 7.9693e-04 - 2s/epoch - 943us/step
# Epoch 26/50
# 2018/2018 - 2s - loss: 7.9653e-04 - 2s/epoch - 904us/step
# Epoch 27/50
# 2018/2018 - 2s - loss: 7.9651e-04 - 2s/epoch - 890us/step
# Epoch 28/50
# 2018/2018 - 2s - loss: 7.9657e-04 - 2s/epoch - 874us/step
# Epoch 29/50
# 2018/2018 - 2s - loss: 7.9625e-04 - 2s/epoch - 868us/step
# Epoch 30/50
# 2018/2018 - 2s - loss: 7.9607e-04 - 2s/epoch - 876us/step
# Epoch 31/50
# 2018/2018 - 2s - loss: 7.9646e-04 - 2s/epoch - 900us/step
# Epoch 32/50
# 2018/2018 - 2s - loss: 7.9664e-04 - 2s/epoch - 863us/step
# Epoch 33/50
# 2018/2018 - 2s - loss: 7.9663e-04 - 2s/epoch - 848us/step
# Epoch 34/50
# 2018/2018 - 2s - loss: 7.9628e-04 - 2s/epoch - 842us/step
# Epoch 35/50
# 2018/2018 - 2s - loss: 7.9597e-04 - 2s/epoch - 908us/step
# Epoch 36/50
# 2018/2018 - 2s - loss: 7.9623e-04 - 2s/epoch - 897us/step
# Epoch 37/50
# 2018/2018 - 2s - loss: 7.9664e-04 - 2s/epoch - 873us/step
# Epoch 38/50
# 2018/2018 - 2s - loss: 7.9625e-04 - 2s/epoch - 880us/step
# Epoch 39/50
# 2018/2018 - 2s - loss: 7.9585e-04 - 2s/epoch - 888us/step
# Epoch 40/50
# 2018/2018 - 2s - loss: 7.9585e-04 - 2s/epoch - 879us/step
# Epoch 41/50
# 2018/2018 - 2s - loss: 7.9626e-04 - 2s/epoch - 896us/step
# Epoch 42/50
# 2018/2018 - 2s - loss: 7.9643e-04 - 2s/epoch - 897us/step
# Epoch 43/50
# 2018/2018 - 2s - loss: 7.9610e-04 - 2s/epoch - 881us/step
# Epoch 44/50
# 2018/2018 - 2s - loss: 7.9613e-04 - 2s/epoch - 879us/step
# Epoch 45/50
# 2018/2018 - 2s - loss: 7.9596e-04 - 2s/epoch - 878us/step
# Epoch 46/50
# 2018/2018 - 2s - loss: 7.9605e-04 - 2s/epoch - 881us/step
# Epoch 47/50
# 2018/2018 - 2s - loss: 7.9617e-04 - 2s/epoch - 884us/step
# Epoch 48/50
# 2018/2018 - 2s - loss: 7.9577e-04 - 2s/epoch - 860us/step
# Epoch 49/50
# 2018/2018 - 2s - loss: 7.9613e-04 - 2s/epoch - 847us/step
# Epoch 50/50
# 2018/2018 - 2s - loss: 7.9620e-04 - 2s/epoch - 839us/step
# 8071/8071 [==============================] - 5s 633us/step
# 2018/2018 [==============================] - 1s 642us/step

# %%
# Calculate RMSE
trainRMSE = np.sqrt(mean_squared_error(trainY_inv[0], trainPredict[:,0]))
testRMSE = np.sqrt(mean_squared_error(testY_inv[0], testPredict[:,0]))

print(f'Train RMSE: {trainRMSE}')
print(f'Test RMSE: {testRMSE}')

# Calculate the time difference between consecutive timestamps
time_diff = data.index.to_series().diff()

# Check if there is a delay between timestamps
delay = time_diff.max()

if delay.total_seconds() > 0:
    print(f"There is a delay of {delay.total_seconds()} seconds between timestamps.")
else:
    print("There is no delay between timestamps.")
# Out:
# Train RMSE: 1.8011850165949874
# Test RMSE: 1.3254374532429236
# There is a delay of 1.457 seconds between timestamps.

# %%
time_diff.plot()
plt.xlabel('Timestamp')
plt.ylabel('Delay (seconds)')
plt.title('Delay between Consecutive Timestamps')
plt.show()

# %%
# Plotting
plt.figure(figsize=(15, 6))

# Use the timestamp range corresponding to the test data for x-axis
timestamps = data.index[train_size+look_back:train_size+look_back+len(testPredict)]

plt.plot(timestamps, testY_inv[0], label='Actual Test Data')
plt.plot(timestamps, testPredict.flatten(), label='Predicted Test Data', color='red')
plt.legend()
plt.title('LSTM Ask Predictions vs Actual Values')
plt.xlabel('Time')
plt.ylabel('Ask Price')
plt.show()

# %%
# Select a small number of predicted values to plot
num_values = 100
selected_timestamps = timestamps[:num_values]
selected_testPredict = testPredict[:num_values]
selected_testY_inv = testY_inv[0][:num_values]

# Plotting
plt.figure(figsize=(15, 6))
plt.plot(selected_timestamps, selected_testY_inv, label='Actual Test Data')
plt.plot(selected_timestamps, selected_testPredict.flatten(), label='Predicted Test Data', color='red')
plt.legend()
plt.title('LSTM Ask Predictions vs Actual Values')
plt.xlabel('Time')
plt.ylabel('Ask Price')
plt.xticks(rotation=45)  # Rotate x-axis labels for better visibility
plt.show()
