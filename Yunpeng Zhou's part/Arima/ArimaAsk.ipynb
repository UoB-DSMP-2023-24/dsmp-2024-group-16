# %%
import pandas as pd
from statsmodels.tsa.arima.model import ARIMA
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import mean_squared_error
# Out:
# C:\Users\Wilson\AppData\Local\Temp\ipykernel_20804\4273999478.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# Load the dataset
file_path = 'result.csv'
data = pd.read_csv(file_path)

# Forward-fill the missing 'Bid' values
data['Ask'] = data['Ask'].fillna(method='ffill').dropna()

# Convert 'Timestamp' to a datetime type, setting an arbitrary start date
data['Timestamp'] = pd.to_timedelta(data['Timestamp'], unit='s') + pd.Timestamp('2025-01-02 00:00')
data.set_index('Timestamp', inplace=True)

# Resampling to a consistent frequency, using forward fill for missing values
data = data['Ask'].asfreq('S', method='ffill')
# Out:
# C:\Users\Wilson\AppData\Local\Temp\ipykernel_20804\1314496239.py:6: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data['Ask'] = data['Ask'].fillna(method='ffill').dropna()
# C:\Users\Wilson\AppData\Local\Temp\ipykernel_20804\1314496239.py:13: FutureWarning: 'S' is deprecated and will be removed in a future version, please use 's' instead.
#   data = data['Ask'].asfreq('S', method='ffill')

# %%
# Split the data into training and testing sets (95% train, 5% test)
split_point = int(len(data) * 0.8)
train_data, test_data = data[:split_point], data[split_point:]

# Ensure the indices are monotonically increasing and remove any duplicates
train_data = train_data.sort_index()
test_data = test_data.sort_index()
train_data = train_data[~train_data.index.duplicated(keep='first')]

# Initialize the history with the training data
history = train_data.copy()

# Define the frequency of model updates
update_frequency = 5

# Preallocate space for predictions for performance optimization
predictions = [None] * len(test_data)

# Start rolling forecast with updates every 5 steps
for t in range(0, len(test_data), update_frequency):
    # Fit the ARIMA model on the current history
    model = ARIMA(history, order=(1,1,1))
    model_fit = model.fit()
    
    # Make predictions for the next 5 steps
    next_steps_predictions = model_fit.forecast(steps=update_frequency)
    
    # Store the predictions
    if t + update_frequency < len(test_data):
        predictions[t:t+update_frequency] = next_steps_predictions
    else:
        predictions[t:] = next_steps_predictions[:len(test_data)-t]
    
    # Update the history with the new observations
    if t + update_frequency < len(test_data):
        new_history = test_data[t:t+update_frequency]
        history = pd.concat([history, new_history])
    print(f'Forecast step: {t}')

# Convert predictions to a Series for easy plotting
predictions_series = pd.Series(predictions, index=test_data.index)
# Out:
# Forecast step: 0
# Forecast step: 5
# Forecast step: 10
# Forecast step: 15
# Forecast step: 20
# Forecast step: 25
# Forecast step: 30
# Forecast step: 35
# Forecast step: 40
# Forecast step: 45
# Forecast step: 50
# Forecast step: 55
# Forecast step: 60
# Forecast step: 65
# Forecast step: 70
# Forecast step: 75
# Forecast step: 80
# Forecast step: 85
# Forecast step: 90
# Forecast step: 95
# Forecast step: 100
# Forecast step: 105
# Forecast step: 110
# Forecast step: 115
# Forecast step: 120
# Forecast step: 125
# Forecast step: 130
# Forecast step: 135
# Forecast step: 140
# Forecast step: 145
# Forecast step: 150
# Forecast step: 155
# Forecast step: 160
# Forecast step: 165
# Forecast step: 170
# Forecast step: 175
# Forecast step: 180
# Forecast step: 185
# Forecast step: 190
# Forecast step: 195
# Forecast step: 200
# Forecast step: 205
# Forecast step: 210
# Forecast step: 215
# Forecast step: 220
# Forecast step: 225
# Forecast step: 230
# Forecast step: 235
# Forecast step: 240
# Forecast step: 245
# Forecast step: 250
# Forecast step: 255
# Forecast step: 260
# Forecast step: 265
# Forecast step: 270
# Forecast step: 275
# Forecast step: 280
# Forecast step: 285
# Forecast step: 290
# Forecast step: 295
# Forecast step: 300
# Forecast step: 305
# Forecast step: 310
# Forecast step: 315
# Forecast step: 320
# Forecast step: 325
# Forecast step: 330
# Forecast step: 335
# Forecast step: 340
# Forecast step: 345
# Forecast step: 350
# Forecast step: 355
# Forecast step: 360
# Forecast step: 365
# Forecast step: 370
# Forecast step: 375
# Forecast step: 380
# Forecast step: 385
# Forecast step: 390
# Forecast step: 395
# Forecast step: 400
# Forecast step: 405
# Forecast step: 410
# Forecast step: 415
# Forecast step: 420
# Forecast step: 425
# Forecast step: 430
# Forecast step: 435
# Forecast step: 440
# Forecast step: 445
# Forecast step: 450
# Forecast step: 455
# Forecast step: 460
# Forecast step: 465
# Forecast step: 470
# Forecast step: 475
# Forecast step: 480
# Forecast step: 485
# Forecast step: 490
# Forecast step: 495
# Forecast step: 500
# Forecast step: 505
# Forecast step: 510
# Forecast step: 515
# Forecast step: 520
# Forecast step: 525
# Forecast step: 530
# Forecast step: 535
# Forecast step: 540
# Forecast step: 545
# Forecast step: 550
# Forecast step: 555
# Forecast step: 560
# Forecast step: 565
# Forecast step: 570
# Forecast step: 575
# Forecast step: 580
# Forecast step: 585
# Forecast step: 590
# Forecast step: 595
# Forecast step: 600
# Forecast step: 605
# Forecast step: 610
# Forecast step: 615
# Forecast step: 620
# Forecast step: 625
# Forecast step: 630
# Forecast step: 635
# Forecast step: 640
# Forecast step: 645
# Forecast step: 650
# Forecast step: 655
# Forecast step: 660
# Forecast step: 665
# Forecast step: 670
# Forecast step: 675
# Forecast step: 680
# Forecast step: 685
# Forecast step: 690
# Forecast step: 695
# Forecast step: 700
# Forecast step: 705
# Forecast step: 710
# Forecast step: 715
# Forecast step: 720
# Forecast step: 725
# Forecast step: 730
# Forecast step: 735
# Forecast step: 740
# Forecast step: 745
# Forecast step: 750
# Forecast step: 755
# Forecast step: 760
# Forecast step: 765
# Forecast step: 770
# Forecast step: 775
# Forecast step: 780
# Forecast step: 785
# Forecast step: 790
# Forecast step: 795
# Forecast step: 800
# Forecast step: 805
# Forecast step: 810
# Forecast step: 815
# Forecast step: 820
# Forecast step: 825
# Forecast step: 830
# Forecast step: 835
# Forecast step: 840
# Forecast step: 845
# Forecast step: 850
# Forecast step: 855
# Forecast step: 860
# Forecast step: 865
# Forecast step: 870
# Forecast step: 875
# Forecast step: 880
# Forecast step: 885
# Forecast step: 890
# Forecast step: 895
# Forecast step: 900
# Forecast step: 905
# Forecast step: 910
# Forecast step: 915
# Forecast step: 920
# Forecast step: 925
# Forecast step: 930
# Forecast step: 935
# Forecast step: 940
# Forecast step: 945
# Forecast step: 950
# Forecast step: 955
# Forecast step: 960
# Forecast step: 965
# Forecast step: 970
# Forecast step: 975
# Forecast step: 980
# Forecast step: 985
# Forecast step: 990
# Forecast step: 995
# Forecast step: 1000
# Forecast step: 1005
# Forecast step: 1010
# Forecast step: 1015
# Forecast step: 1020
# Forecast step: 1025
# Forecast step: 1030
# Forecast step: 1035
# Forecast step: 1040
# Forecast step: 1045
# Forecast step: 1050
# Forecast step: 1055
# Forecast step: 1060
# Forecast step: 1065
# Forecast step: 1070
# Forecast step: 1075
# Forecast step: 1080
# Forecast step: 1085
# Forecast step: 1090
# Forecast step: 1095
# Forecast step: 1100
# Forecast step: 1105
# Forecast step: 1110
# Forecast step: 1115
# Forecast step: 1120
# Forecast step: 1125
# Forecast step: 1130
# Forecast step: 1135
# Forecast step: 1140
# Forecast step: 1145
# Forecast step: 1150
# Forecast step: 1155
# Forecast step: 1160
# Forecast step: 1165
# Forecast step: 1170
# Forecast step: 1175
# Forecast step: 1180
# Forecast step: 1185
# Forecast step: 1190
# Forecast step: 1195
# Forecast step: 1200
# Forecast step: 1205
# Forecast step: 1210
# Forecast step: 1215
# Forecast step: 1220
# Forecast step: 1225
# Forecast step: 1230
# Forecast step: 1235
# Forecast step: 1240
# Forecast step: 1245
# Forecast step: 1250
# Forecast step: 1255
# Forecast step: 1260
# Forecast step: 1265
# Forecast step: 1270
# Forecast step: 1275
# Forecast step: 1280
# Forecast step: 1285
# Forecast step: 1290
# Forecast step: 1295
# Forecast step: 1300
# Forecast step: 1305
# Forecast step: 1310
# Forecast step: 1315
# Forecast step: 1320
# Forecast step: 1325
# Forecast step: 1330
# Forecast step: 1335
# Forecast step: 1340
# Forecast step: 1345
# Forecast step: 1350
# Forecast step: 1355
# Forecast step: 1360
# Forecast step: 1365
# Forecast step: 1370
# Forecast step: 1375
# Forecast step: 1380
# Forecast step: 1385
# Forecast step: 1390
# Forecast step: 1395
# Forecast step: 1400
# Forecast step: 1405
# Forecast step: 1410
# Forecast step: 1415
# Forecast step: 1420
# Forecast step: 1425
# Forecast step: 1430
# Forecast step: 1435
# Forecast step: 1440
# Forecast step: 1445
# Forecast step: 1450
# Forecast step: 1455
# Forecast step: 1460
# Forecast step: 1465
# Forecast step: 1470
# Forecast step: 1475
# Forecast step: 1480
# Forecast step: 1485
# Forecast step: 1490
# Forecast step: 1495
# Forecast step: 1500
# Forecast step: 1505
# Forecast step: 1510
# Forecast step: 1515
# Forecast step: 1520
# Forecast step: 1525
# Forecast step: 1530
# Forecast step: 1535
# Forecast step: 1540
# Forecast step: 1545
# Forecast step: 1550
# Forecast step: 1555
# Forecast step: 1560
# Forecast step: 1565
# Forecast step: 1570
# Forecast step: 1575
# Forecast step: 1580
# Forecast step: 1585
# Forecast step: 1590
# Forecast step: 1595
# Forecast step: 1600
# Forecast step: 1605
# Forecast step: 1610
# Forecast step: 1615
# Forecast step: 1620
# Forecast step: 1625
# Forecast step: 1630
# Forecast step: 1635
# Forecast step: 1640
# Forecast step: 1645
# Forecast step: 1650
# Forecast step: 1655
# Forecast step: 1660
# Forecast step: 1665
# Forecast step: 1670
# Forecast step: 1675
# Forecast step: 1680
# Forecast step: 1685
# Forecast step: 1690
# Forecast step: 1695
# Forecast step: 1700
# Forecast step: 1705
# Forecast step: 1710
# Forecast step: 1715
# Forecast step: 1720
# Forecast step: 1725
# Forecast step: 1730
# Forecast step: 1735
# Forecast step: 1740
# Forecast step: 1745
# Forecast step: 1750
# Forecast step: 1755
# Forecast step: 1760
# Forecast step: 1765
# Forecast step: 1770
# Forecast step: 1775
# Forecast step: 1780
# Forecast step: 1785
# Forecast step: 1790
# Forecast step: 1795
# Forecast step: 1800
# Forecast step: 1805
# Forecast step: 1810
# Forecast step: 1815
# Forecast step: 1820
# Forecast step: 1825
# Forecast step: 1830
# Forecast step: 1835
# Forecast step: 1840
# Forecast step: 1845
# Forecast step: 1850
# Forecast step: 1855
# Forecast step: 1860
# Forecast step: 1865
# Forecast step: 1870
# Forecast step: 1875
# Forecast step: 1880
# Forecast step: 1885
# Forecast step: 1890
# Forecast step: 1895
# Forecast step: 1900
# Forecast step: 1905
# Forecast step: 1910
# Forecast step: 1915
# Forecast step: 1920
# Forecast step: 1925
# Forecast step: 1930
# Forecast step: 1935
# Forecast step: 1940
# Forecast step: 1945
# Forecast step: 1950
# Forecast step: 1955
# Forecast step: 1960
# Forecast step: 1965
# Forecast step: 1970
# Forecast step: 1975
# Forecast step: 1980
# Forecast step: 1985
# Forecast step: 1990
# Forecast step: 1995
# Forecast step: 2000
# Forecast step: 2005
# Forecast step: 2010
# Forecast step: 2015
# Forecast step: 2020
# Forecast step: 2025
# Forecast step: 2030
# Forecast step: 2035
# Forecast step: 2040
# Forecast step: 2045
# Forecast step: 2050
# Forecast step: 2055
# Forecast step: 2060
# Forecast step: 2065
# Forecast step: 2070
# Forecast step: 2075
# Forecast step: 2080
# Forecast step: 2085
# Forecast step: 2090
# Forecast step: 2095
# Forecast step: 2100
# Forecast step: 2105
# Forecast step: 2110
# Forecast step: 2115
# Forecast step: 2120
# Forecast step: 2125
# Forecast step: 2130
# Forecast step: 2135
# Forecast step: 2140
# Forecast step: 2145
# Forecast step: 2150
# Forecast step: 2155
# Forecast step: 2160
# Forecast step: 2165
# Forecast step: 2170
# Forecast step: 2175
# Forecast step: 2180
# Forecast step: 2185
# Forecast step: 2190
# Forecast step: 2195
# Forecast step: 2200
# Forecast step: 2205
# Forecast step: 2210
# Forecast step: 2215
# Forecast step: 2220
# Forecast step: 2225
# Forecast step: 2230
# Forecast step: 2235
# Forecast step: 2240
# Forecast step: 2245
# Forecast step: 2250
# Forecast step: 2255
# Forecast step: 2260
# Forecast step: 2265
# Forecast step: 2270
# Forecast step: 2275
# Forecast step: 2280
# Forecast step: 2285
# Forecast step: 2290
# Forecast step: 2295
# Forecast step: 2300
# Forecast step: 2305
# Forecast step: 2310
# Forecast step: 2315
# Forecast step: 2320
# Forecast step: 2325
# Forecast step: 2330
# Forecast step: 2335
# Forecast step: 2340
# Forecast step: 2345
# Forecast step: 2350
# Forecast step: 2355
# Forecast step: 2360
# Forecast step: 2365
# Forecast step: 2370
# Forecast step: 2375
# Forecast step: 2380
# Forecast step: 2385
# Forecast step: 2390
# Forecast step: 2395
# Forecast step: 2400
# Forecast step: 2405
# Forecast step: 2410
# Forecast step: 2415
# Forecast step: 2420
# Forecast step: 2425
# Forecast step: 2430
# Forecast step: 2435
# Forecast step: 2440
# Forecast step: 2445
# Forecast step: 2450
# Forecast step: 2455
# Forecast step: 2460
# Forecast step: 2465
# Forecast step: 2470
# Forecast step: 2475
# Forecast step: 2480
# Forecast step: 2485
# Forecast step: 2490
# Forecast step: 2495
# Forecast step: 2500
# Forecast step: 2505
# Forecast step: 2510
# Forecast step: 2515
# Forecast step: 2520
# Forecast step: 2525
# Forecast step: 2530
# Forecast step: 2535
# Forecast step: 2540
# Forecast step: 2545
# Forecast step: 2550
# Forecast step: 2555
# Forecast step: 2560
# Forecast step: 2565
# Forecast step: 2570
# Forecast step: 2575
# Forecast step: 2580
# Forecast step: 2585
# Forecast step: 2590
# Forecast step: 2595
# Forecast step: 2600
# Forecast step: 2605
# Forecast step: 2610
# Forecast step: 2615
# Forecast step: 2620
# Forecast step: 2625
# Forecast step: 2630
# Forecast step: 2635
# Forecast step: 2640
# Forecast step: 2645
# Forecast step: 2650
# Forecast step: 2655
# Forecast step: 2660
# Forecast step: 2665
# Forecast step: 2670
# Forecast step: 2675
# Forecast step: 2680
# Forecast step: 2685
# Forecast step: 2690
# Forecast step: 2695
# Forecast step: 2700
# Forecast step: 2705
# Forecast step: 2710
# Forecast step: 2715
# Forecast step: 2720
# Forecast step: 2725
# Forecast step: 2730
# Forecast step: 2735
# Forecast step: 2740
# Forecast step: 2745
# Forecast step: 2750
# Forecast step: 2755
# Forecast step: 2760
# Forecast step: 2765
# Forecast step: 2770
# Forecast step: 2775
# Forecast step: 2780
# Forecast step: 2785
# Forecast step: 2790
# Forecast step: 2795
# Forecast step: 2800
# Forecast step: 2805
# Forecast step: 2810
# Forecast step: 2815
# Forecast step: 2820
# Forecast step: 2825
# Forecast step: 2830
# Forecast step: 2835
# Forecast step: 2840
# Forecast step: 2845
# Forecast step: 2850
# Forecast step: 2855
# Forecast step: 2860
# Forecast step: 2865
# Forecast step: 2870
# Forecast step: 2875
# Forecast step: 2880
# Forecast step: 2885
# Forecast step: 2890
# Forecast step: 2895
# Forecast step: 2900
# Forecast step: 2905
# Forecast step: 2910
# Forecast step: 2915
# Forecast step: 2920
# Forecast step: 2925
# Forecast step: 2930
# Forecast step: 2935
# Forecast step: 2940
# Forecast step: 2945
# Forecast step: 2950
# Forecast step: 2955
# Forecast step: 2960
# Forecast step: 2965
# Forecast step: 2970
# Forecast step: 2975
# Forecast step: 2980
# Forecast step: 2985
# Forecast step: 2990
# Forecast step: 2995
# Forecast step: 3000
# Forecast step: 3005
# Forecast step: 3010
# Forecast step: 3015
# Forecast step: 3020
# Forecast step: 3025
# Forecast step: 3030
# Forecast step: 3035
# Forecast step: 3040
# Forecast step: 3045
# Forecast step: 3050
# Forecast step: 3055
# Forecast step: 3060
# Forecast step: 3065
# Forecast step: 3070
# Forecast step: 3075
# Forecast step: 3080
# Forecast step: 3085
# Forecast step: 3090
# Forecast step: 3095
# Forecast step: 3100
# Forecast step: 3105
# Forecast step: 3110
# Forecast step: 3115
# Forecast step: 3120
# Forecast step: 3125
# Forecast step: 3130
# Forecast step: 3135
# Forecast step: 3140
# Forecast step: 3145
# Forecast step: 3150
# Forecast step: 3155
# Forecast step: 3160
# Forecast step: 3165
# Forecast step: 3170
# Forecast step: 3175
# Forecast step: 3180
# Forecast step: 3185
# Forecast step: 3190
# Forecast step: 3195
# Forecast step: 3200
# Forecast step: 3205
# Forecast step: 3210
# Forecast step: 3215
# Forecast step: 3220
# Forecast step: 3225
# Forecast step: 3230
# Forecast step: 3235
# Forecast step: 3240
# Forecast step: 3245
# Forecast step: 3250
# Forecast step: 3255
# Forecast step: 3260
# Forecast step: 3265
# Forecast step: 3270
# Forecast step: 3275
# Forecast step: 3280
# Forecast step: 3285
# Forecast step: 3290
# Forecast step: 3295
# Forecast step: 3300
# Forecast step: 3305
# Forecast step: 3310
# Forecast step: 3315
# Forecast step: 3320
# Forecast step: 3325
# Forecast step: 3330
# Forecast step: 3335
# Forecast step: 3340
# Forecast step: 3345
# Forecast step: 3350
# Forecast step: 3355
# Forecast step: 3360
# Forecast step: 3365
# Forecast step: 3370
# Forecast step: 3375
# Forecast step: 3380
# Forecast step: 3385
# Forecast step: 3390
# Forecast step: 3395
# Forecast step: 3400
# Forecast step: 3405
# Forecast step: 3410
# Forecast step: 3415
# Forecast step: 3420
# Forecast step: 3425
# Forecast step: 3430
# Forecast step: 3435
# Forecast step: 3440
# Forecast step: 3445
# Forecast step: 3450
# Forecast step: 3455
# Forecast step: 3460
# Forecast step: 3465
# Forecast step: 3470
# Forecast step: 3475
# Forecast step: 3480
# Forecast step: 3485
# Forecast step: 3490
# Forecast step: 3495
# Forecast step: 3500
# Forecast step: 3505
# Forecast step: 3510
# Forecast step: 3515
# Forecast step: 3520
# Forecast step: 3525
# Forecast step: 3530
# Forecast step: 3535
# Forecast step: 3540
# Forecast step: 3545
# Forecast step: 3550
# Forecast step: 3555
# Forecast step: 3560
# Forecast step: 3565
# Forecast step: 3570
# Forecast step: 3575
# Forecast step: 3580
# Forecast step: 3585
# Forecast step: 3590
# Forecast step: 3595
# Forecast step: 3600
# Forecast step: 3605
# Forecast step: 3610
# Forecast step: 3615
# Forecast step: 3620
# Forecast step: 3625
# Forecast step: 3630
# Forecast step: 3635
# Forecast step: 3640
# Forecast step: 3645
# Forecast step: 3650
# Forecast step: 3655
# Forecast step: 3660
# Forecast step: 3665
# Forecast step: 3670
# Forecast step: 3675
# Forecast step: 3680
# Forecast step: 3685
# Forecast step: 3690
# Forecast step: 3695
# Forecast step: 3700
# Forecast step: 3705
# Forecast step: 3710
# Forecast step: 3715
# Forecast step: 3720
# Forecast step: 3725
# Forecast step: 3730
# Forecast step: 3735
# Forecast step: 3740
# Forecast step: 3745
# Forecast step: 3750
# Forecast step: 3755
# Forecast step: 3760
# Forecast step: 3765
# Forecast step: 3770
# Forecast step: 3775
# Forecast step: 3780
# Forecast step: 3785
# Forecast step: 3790
# Forecast step: 3795
# Forecast step: 3800
# Forecast step: 3805
# Forecast step: 3810
# Forecast step: 3815
# Forecast step: 3820
# Forecast step: 3825
# Forecast step: 3830
# Forecast step: 3835
# Forecast step: 3840
# Forecast step: 3845
# Forecast step: 3850
# Forecast step: 3855
# Forecast step: 3860
# Forecast step: 3865
# Forecast step: 3870
# Forecast step: 3875
# Forecast step: 3880
# Forecast step: 3885
# Forecast step: 3890
# Forecast step: 3895
# Forecast step: 3900
# Forecast step: 3905
# Forecast step: 3910
# Forecast step: 3915
# Forecast step: 3920
# Forecast step: 3925
# Forecast step: 3930
# Forecast step: 3935
# Forecast step: 3940
# Forecast step: 3945
# Forecast step: 3950
# Forecast step: 3955
# Forecast step: 3960
# Forecast step: 3965
# Forecast step: 3970
# Forecast step: 3975
# Forecast step: 3980
# Forecast step: 3985
# Forecast step: 3990
# Forecast step: 3995
# Forecast step: 4000
# Forecast step: 4005
# Forecast step: 4010
# Forecast step: 4015
# Forecast step: 4020
# Forecast step: 4025
# Forecast step: 4030
# Forecast step: 4035
# Forecast step: 4040
# Forecast step: 4045
# Forecast step: 4050
# Forecast step: 4055
# Forecast step: 4060
# Forecast step: 4065
# Forecast step: 4070
# Forecast step: 4075
# Forecast step: 4080
# Forecast step: 4085
# Forecast step: 4090
# Forecast step: 4095
# Forecast step: 4100
# Forecast step: 4105
# Forecast step: 4110
# Forecast step: 4115
# Forecast step: 4120
# Forecast step: 4125
# Forecast step: 4130
# Forecast step: 4135
# Forecast step: 4140
# Forecast step: 4145
# Forecast step: 4150
# Forecast step: 4155
# Forecast step: 4160
# Forecast step: 4165
# Forecast step: 4170
# Forecast step: 4175
# Forecast step: 4180
# Forecast step: 4185
# Forecast step: 4190
# Forecast step: 4195
# Forecast step: 4200
# Forecast step: 4205
# Forecast step: 4210
# Forecast step: 4215
# Forecast step: 4220
# Forecast step: 4225
# Forecast step: 4230
# Forecast step: 4235
# Forecast step: 4240
# Forecast step: 4245
# Forecast step: 4250
# Forecast step: 4255
# Forecast step: 4260
# Forecast step: 4265
# Forecast step: 4270
# Forecast step: 4275
# Forecast step: 4280
# Forecast step: 4285
# Forecast step: 4290
# Forecast step: 4295
# Forecast step: 4300
# Forecast step: 4305
# Forecast step: 4310
# Forecast step: 4315
# Forecast step: 4320
# Forecast step: 4325
# Forecast step: 4330
# Forecast step: 4335
# Forecast step: 4340
# Forecast step: 4345
# Forecast step: 4350
# Forecast step: 4355
# Forecast step: 4360
# Forecast step: 4365
# Forecast step: 4370
# Forecast step: 4375
# Forecast step: 4380
# Forecast step: 4385
# Forecast step: 4390
# Forecast step: 4395
# Forecast step: 4400
# Forecast step: 4405
# Forecast step: 4410
# Forecast step: 4415
# Forecast step: 4420
# Forecast step: 4425
# Forecast step: 4430
# Forecast step: 4435
# Forecast step: 4440
# Forecast step: 4445
# Forecast step: 4450
# Forecast step: 4455
# Forecast step: 4460
# Forecast step: 4465
# Forecast step: 4470
# Forecast step: 4475
# Forecast step: 4480
# Forecast step: 4485
# Forecast step: 4490
# Forecast step: 4495
# Forecast step: 4500
# Forecast step: 4505
# Forecast step: 4510
# Forecast step: 4515
# Forecast step: 4520
# Forecast step: 4525
# Forecast step: 4530
# Forecast step: 4535
# Forecast step: 4540
# Forecast step: 4545
# Forecast step: 4550
# Forecast step: 4555
# Forecast step: 4560
# Forecast step: 4565
# Forecast step: 4570
# Forecast step: 4575
# Forecast step: 4580
# Forecast step: 4585
# Forecast step: 4590
# Forecast step: 4595
# Forecast step: 4600
# Forecast step: 4605
# Forecast step: 4610
# Forecast step: 4615
# Forecast step: 4620
# Forecast step: 4625
# Forecast step: 4630
# Forecast step: 4635
# Forecast step: 4640
# Forecast step: 4645
# Forecast step: 4650
# Forecast step: 4655
# Forecast step: 4660
# Forecast step: 4665
# Forecast step: 4670
# Forecast step: 4675
# Forecast step: 4680
# Forecast step: 4685
# Forecast step: 4690
# Forecast step: 4695
# Forecast step: 4700
# Forecast step: 4705
# Forecast step: 4710
# Forecast step: 4715
# Forecast step: 4720
# Forecast step: 4725
# Forecast step: 4730
# Forecast step: 4735
# Forecast step: 4740
# Forecast step: 4745
# Forecast step: 4750
# Forecast step: 4755
# Forecast step: 4760
# Forecast step: 4765
# Forecast step: 4770
# Forecast step: 4775
# Forecast step: 4780
# Forecast step: 4785
# Forecast step: 4790
# Forecast step: 4795
# Forecast step: 4800
# Forecast step: 4805
# Forecast step: 4810
# Forecast step: 4815
# Forecast step: 4820
# Forecast step: 4825
# Forecast step: 4830
# Forecast step: 4835
# Forecast step: 4840
# Forecast step: 4845
# Forecast step: 4850
# Forecast step: 4855
# Forecast step: 4860
# Forecast step: 4865
# Forecast step: 4870
# Forecast step: 4875
# Forecast step: 4880
# Forecast step: 4885
# Forecast step: 4890
# Forecast step: 4895
# Forecast step: 4900
# Forecast step: 4905
# Forecast step: 4910
# Forecast step: 4915
# Forecast step: 4920
# Forecast step: 4925
# Forecast step: 4930
# Forecast step: 4935
# Forecast step: 4940
# Forecast step: 4945
# Forecast step: 4950
# Forecast step: 4955
# Forecast step: 4960
# Forecast step: 4965
# Forecast step: 4970
# Forecast step: 4975
# Forecast step: 4980
# Forecast step: 4985
# Forecast step: 4990
# Forecast step: 4995
# Forecast step: 5000
# Forecast step: 5005
# Forecast step: 5010
# Forecast step: 5015
# Forecast step: 5020
# Forecast step: 5025
# Forecast step: 5030
# Forecast step: 5035
# Forecast step: 5040
# Forecast step: 5045
# Forecast step: 5050
# Forecast step: 5055
# Forecast step: 5060
# Forecast step: 5065
# Forecast step: 5070
# Forecast step: 5075
# Forecast step: 5080
# Forecast step: 5085
# Forecast step: 5090
# Forecast step: 5095
# Forecast step: 5100
# Forecast step: 5105
# Forecast step: 5110
# Forecast step: 5115
# Forecast step: 5120
# Forecast step: 5125
# Forecast step: 5130
# Forecast step: 5135
# Forecast step: 5140
# Forecast step: 5145
# Forecast step: 5150
# Forecast step: 5155
# Forecast step: 5160
# Forecast step: 5165
# Forecast step: 5170
# Forecast step: 5175
# Forecast step: 5180
# Forecast step: 5185
# Forecast step: 5190
# Forecast step: 5195
# Forecast step: 5200
# Forecast step: 5205
# Forecast step: 5210
# Forecast step: 5215
# Forecast step: 5220
# Forecast step: 5225
# Forecast step: 5230
# Forecast step: 5235
# Forecast step: 5240
# Forecast step: 5245
# Forecast step: 5250
# Forecast step: 5255
# Forecast step: 5260
# Forecast step: 5265
# Forecast step: 5270
# Forecast step: 5275
# Forecast step: 5280
# Forecast step: 5285
# Forecast step: 5290
# Forecast step: 5295
# Forecast step: 5300
# Forecast step: 5305
# Forecast step: 5310
# Forecast step: 5315
# Forecast step: 5320
# Forecast step: 5325
# Forecast step: 5330
# Forecast step: 5335
# Forecast step: 5340
# Forecast step: 5345
# Forecast step: 5350
# Forecast step: 5355
# Forecast step: 5360
# Forecast step: 5365
# Forecast step: 5370
# Forecast step: 5375
# Forecast step: 5380
# Forecast step: 5385
# Forecast step: 5390
# Forecast step: 5395
# Forecast step: 5400
# Forecast step: 5405
# Forecast step: 5410
# Forecast step: 5415
# Forecast step: 5420
# Forecast step: 5425
# Forecast step: 5430
# Forecast step: 5435
# Forecast step: 5440
# Forecast step: 5445
# Forecast step: 5450
# Forecast step: 5455
# Forecast step: 5460
# Forecast step: 5465
# Forecast step: 5470
# Forecast step: 5475
# Forecast step: 5480
# Forecast step: 5485
# Forecast step: 5490
# Forecast step: 5495
# Forecast step: 5500
# Forecast step: 5505
# Forecast step: 5510
# Forecast step: 5515
# Forecast step: 5520
# Forecast step: 5525
# Forecast step: 5530
# Forecast step: 5535
# Forecast step: 5540
# Forecast step: 5545
# Forecast step: 5550
# Forecast step: 5555
# Forecast step: 5560
# Forecast step: 5565
# Forecast step: 5570
# Forecast step: 5575
# Forecast step: 5580
# Forecast step: 5585
# Forecast step: 5590
# Forecast step: 5595
# Forecast step: 5600
# Forecast step: 5605
# Forecast step: 5610
# Forecast step: 5615
# Forecast step: 5620
# Forecast step: 5625
# Forecast step: 5630
# Forecast step: 5635
# Forecast step: 5640
# Forecast step: 5645
# Forecast step: 5650
# Forecast step: 5655
# Forecast step: 5660
# Forecast step: 5665
# Forecast step: 5670
# Forecast step: 5675
# Forecast step: 5680
# Forecast step: 5685
# Forecast step: 5690
# Forecast step: 5695
# Forecast step: 5700
# Forecast step: 5705
# Forecast step: 5710
# Forecast step: 5715
# Forecast step: 5720
# Forecast step: 5725
# Forecast step: 5730
# Forecast step: 5735
# Forecast step: 5740
# Forecast step: 5745
# Forecast step: 5750
# Forecast step: 5755
# Forecast step: 5760
# Forecast step: 5765
# Forecast step: 5770
# Forecast step: 5775
# Forecast step: 5780
# Forecast step: 5785
# Forecast step: 5790
# Forecast step: 5795
# Forecast step: 5800
# Forecast step: 5805
# Forecast step: 5810
# Forecast step: 5815
# Forecast step: 5820
# Forecast step: 5825
# Forecast step: 5830
# Forecast step: 5835
# Forecast step: 5840
# Forecast step: 5845
# Forecast step: 5850
# Forecast step: 5855
# Forecast step: 5860
# Forecast step: 5865
# Forecast step: 5870
# Forecast step: 5875
# Forecast step: 5880
# Forecast step: 5885
# Forecast step: 5890
# Forecast step: 5895
# Forecast step: 5900
# Forecast step: 5905
# Forecast step: 5910
# Forecast step: 5915
# Forecast step: 5920
# Forecast step: 5925
# Forecast step: 5930
# Forecast step: 5935
# Forecast step: 5940
# Forecast step: 5945
# Forecast step: 5950
# Forecast step: 5955
# Forecast step: 5960
# Forecast step: 5965
# Forecast step: 5970
# Forecast step: 5975
# Forecast step: 5980
# Forecast step: 5985
# Forecast step: 5990
# Forecast step: 5995
# Forecast step: 6000
# Forecast step: 6005
# Forecast step: 6010
# Forecast step: 6015
# Forecast step: 6020
# Forecast step: 6025
# Forecast step: 6030
# Forecast step: 6035
# Forecast step: 6040
# Forecast step: 6045
# Forecast step: 6050
# Forecast step: 6055
# Forecast step: 6060
# Forecast step: 6065
# Forecast step: 6070
# Forecast step: 6075
# Forecast step: 6080
# Forecast step: 6085
# Forecast step: 6090
# Forecast step: 6095
# Forecast step: 6100
# Forecast step: 6105
# Forecast step: 6110
# Forecast step: 6115

# %%
# Calculate the RMSE for the predictions
rmse = np.sqrt(mean_squared_error(test_data, predictions_series))
print(f"Test RMSE: {rmse}")

# Plotting the results
plt.figure(figsize=(15, 6))
plt.plot(test_data.index, test_data, label='Actual Test Data')
plt.plot(predictions_series.index, predictions_series, label='Predicted Test Data', color='red')
plt.legend()
plt.title('Ask Price Prediction using Rolling ARIMA')
plt.xlabel('Time')
plt.ylabel('Ask Price')
plt.show()
# Out:
# Test RMSE: 33.55911359667947
